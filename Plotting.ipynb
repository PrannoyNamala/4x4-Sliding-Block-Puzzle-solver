# %% [markdown]
# <a href="https://colab.research.google.com/github/PrannoyNamala/4x4-Sliding-Block-Puzzle-solver/blob/main/Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(30,16))

df_dqn_540 = pd.read_csv("https://raw.githubusercontent.com/AcquayeChristabel/A2C-Exploration/main/storage/storage/Empty/log.csv?token=GHSAT0AAAAAACBVRPBQJH5WRCPWQ75VTU6CZCDICOQ", on_bad_lines='skip')

df_dqn_540.drop([1,3,5,7,9,11,13,15,17], inplace=True)

plt.plot(df_dqn_540['frames'], df_dqn_540['rreturn_mean'], 'o--')
# plt.plot(df_a2c_20000['num_env_steps_sampled'], df_a2c_20000['episode_len_mean'], 'o-', label="A2C 20000")
# plt.plot([-120,55000], [24.32, 24.32], '--', label="Best Performing Fixed Policy Combination")
# plt.plot([-120,55000], [20,20], '--', label="Stopping Condition Target")


# plt.legend()
# plt.title("DQN Model 540 Total Mean Reward Stopping")
# plt.xlim(0,90000)
# plt.ylim(0,1)

plt.xlabel("Number of Training Frames")
plt.ylabel("Returned Reward")

plt.show()

# %%
df_dqn_540.drop([1,3,5,7,9])
# Out:
#    update frames                 FPS duration         rreturn_mean  \
# 0       1   2048   5228.296677358686        0  0.44648437574505806
# 2       2   4096   5429.131965569308        0   0.2911458344509204
# 4       3   6144   4932.118031823025        1   0.4678571458373751
# 6       4   8192  5639.7965140670985        1   0.4407407387539192
# 8       5  10240   5905.346401732982        1   0.6617559501457781
# 10      6  12288   5569.496428103673        2   0.8019366190886833
# 12      7  14336   5474.887723793317        2   0.8712378656401217
# 14      8  16384   6203.413269628103        2   0.8922826087993124
# 16      9  18432   5761.507066116313        3   0.9031250010913526
# 18     10  20480   5056.525553013866        3   0.9311224486754865
# 19     11  22528  5303.7514244293025        4   0.9387623133330509
# 20     12  24576   5860.032562654731        4   0.9402556814930656
# 21     13  26624   5793.862770067557        4   0.9450487035177487
# ...
